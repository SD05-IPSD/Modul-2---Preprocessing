# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

# %%
features = pd.read_csv("/content/features.csv")
labels = pd.read_csv("/content/labels.csv")

# %% [markdown]
# **1️. Tampilkan data yang telah diunduh, kemudian jelaskan semua kolom yang terdapat pada dataset tersebut.**

# %%
features.head().T
# Out:
#                                                          0           1  \
# Unnamed: 0                                               0           1
# Student Id                                            6634        6459
# Marital status                                      single      single
# Application mode                                       1.0         1.0
# Application order                                      3.0         1.0
# Course                                              9773.0         NaN
# Daytime/evening attendance\t                           day         day
# Previous qualification                                 1.0         1.0
# Previous qualification (grade)                         NaN       136.0
# Nacionality                                     Portuguese  Portuguese
# Mother's qualification                                 1.0        19.0
# Father's qualification                                 1.0        19.0
# ...

# %%
labels.head()
# Out:
#      Target
# 0  Graduate
# 1  Graduate
# 2  Graduate
# 3  Graduate
# 4   Dropout

# %% [markdown]
# Penjelasan Kolom Dataset
# Dataset ini terdiri dari beberapa kolom yang memberikan gambaran tentang mahasiswa. Berikut penjelasan setiap kolom:
#
# Unnamed: 0 : Nomor urut atau indeks otomatis dari dataset.
#
# Student Id : ID unik untuk setiap mahasiswa.
#
# Marital status : Status pernikahan mahasiswa (misalnya single, married, dll).
#
# Application mode : Jalur pendaftaran yang digunakan mahasiswa (tes nasional, transfer, jalur mandiri, dll).
#
# Application order : Urutan pilihan program studi saat mahasiswa mendaftar.
#
# Course : Program studi yang dipilih oleh mahasiswa.
#
# Daytime/evening attendance : Waktu kuliah mahasiswa (day = kelas pagi, evening = kelas malam).
#
# Previous qualification : Kualifikasi pendidikan terakhir sebelum masuk universitas.
#
# Previous qualification (grade) : Nilai atau rata-rata nilai pada pendidikan sebelumnya.
#
# Nationality : Kewarganegaraan mahasiswa.
#
# Mother’s qualification : Tingkat pendidikan terakhir ibu mahasiswa.
#
# Father’s qualification : Tingkat pendidikan terakhir ayah mahasiswa.
#
# Mother’s occupation : Pekerjaan ibu mahasiswa.
#
# Father’s occupation : Pekerjaan ayah mahasiswa.
#
# Admission grade : Nilai yang diperoleh saat seleksi masuk universitas.
#
# Displaced : Menunjukkan apakah mahasiswa berasal dari daerah pengungsian/terpencil (1 = ya, 0 = tidak).
#
# Educational special needs : Menunjukkan apakah mahasiswa memiliki kebutuhan khusus (1 = ya, 0 = tidak).
#
# Debtor : Menunjukkan apakah mahasiswa memiliki tunggakan pembayaran (1 = ya, 0 = tidak).
#
# Tuition fees up to date : Apakah mahasiswa sudah melunasi pembayaran biaya kuliah (1 = ya, 0 = tidak).
#
# Gender : Jenis kelamin mahasiswa (male/female).
#
# Scholarship holder : Menunjukkan apakah mahasiswa menerima beasiswa (1 = ya, 0 = tidak).
#
# Age at enrollment : Usia mahasiswa saat mendaftar.
#
# International : Menunjukkan apakah mahasiswa tersebut merupakan mahasiswa internasional (1 = ya, 0 = tidak).
#
# Curricular units 1st sem (credited) : Jumlah mata kuliah semester 1 yang diakui.
#
# Curricular units 1st sem (enrolled) : Jumlah mata kuliah semester 1 yang diambil.
#
# Curricular units 1st sem (evaluations) : Jumlah evaluasi pada semester 1.
#
# Curricular units 1st sem (approved) : Jumlah mata kuliah semester 1 yang lulus.
#
# Curricular units 1st sem (grade) : Rata-rata nilai semester 1.
#
# Curricular units 1st sem (without evaluations) : Jumlah mata kuliah semester 1 tanpa evaluasi.
#
# Curricular units 2nd sem (credited) : Jumlah mata kuliah semester 2 yang diakui.
#
# Curricular units 2nd sem (enrolled) : Jumlah mata kuliah semester 2 yang diambil.
#
# Curricular units 2nd sem (evaluations) : Jumlah evaluasi pada semester 2.
#
# Curricular units 2nd sem (approved) : Jumlah mata kuliah semester 2 yang lulus.
#
# Curricular units 2nd sem (grade) : Rata-rata nilai semester 2.
#
# Curricular units 2nd sem (without evaluations) : Jumlah mata kuliah semester 2 tanpa evaluasi.
#
# Unemployment rate : Tingkat pengangguran di tahun pendaftaran.
#
# Inflation rate : Tingkat inflasi pada tahun pendaftaran.
#
# GDP : Nilai Produk Domestik Bruto nasional pada tahun pendaftaran.
#
# Penjelasan Kolom Dataset Labels
#
# Kolom pada dataset labels berisi informasi status akhir mahasiswa:
#
# Graduate : Mahasiswa telah lulus.
#
# Dropout : Mahasiswa berhenti kuliah sebelum lulus.
#
# Enrolled : Mahasiswa masih aktif kuliah.

# %% [markdown]
# **2️. Lakukan agregasi antara tabel features dengan tabel labels.**

# %%
df = pd.concat([features, labels], axis=1)
df
# Out:
#       Unnamed: 0  Student Id Marital status  Application mode  \
# 0              0        6634         single               1.0
# 1              1        6459         single               1.0
# 2              2        2238         single              42.0
# 3              3        2479         single               1.0
# 4              4        4260         single              44.0
# ...          ...         ...            ...               ...
# 3091        3091        6176         single              44.0
# 3092        3092        8064         single               1.0
# 3093        3093        2103         single               1.0
# 3094        3094        8629         single              39.0
# 3095        3095        6614         single              17.0
#
#       Application order  Course Daytime/evening attendance\t  \
# 0                   3.0  9773.0                          day
# 1                   1.0     NaN                          day
# ...

# %% [markdown]
# **3️. Tampilkan tipe data dari setiap kolom yang terdapat dalam dataset.**

# %%
# Menampilkan tipe data dari setiap kolom pada dataset hasil gabungan
data.dtypes
# Out:
# Unnamed: 0                                          int64
# Student Id                                          int64
# Marital status                                     object
# Application mode                                  float64
# Application order                                 float64
# Course                                            float64
# Daytime/evening attendance\t                       object
# Previous qualification                            float64
# Previous qualification (grade)                    float64
# Nacionality                                        object
# Mother's qualification                            float64
# Father's qualification                            float64
# Mother's occupation                               float64
# Father's occupation                               float64
# Admission grade                                   float64
# Displaced                                         float64
# ...

# %% [markdown]
# **4. Tampilkan statistik deskriptif dari dataset dan berikan analisis singkat mengenai hasilnya.**

# %%
# Menampilkan statistik deskriptif dari dataset
data.describe().T
# Out:
#                                                  count         mean  \
# Unnamed: 0                                      3096.0  1547.500000
# Student Id                                      3096.0  5470.623062
# Application mode                                2924.0    18.785568
# Application order                               2988.0     1.734940
# Course                                          2944.0  8817.929348
# Previous qualification                          2973.0     4.685503
# Previous qualification (grade)                  3011.0   132.647293
# Mother's qualification                          2951.0    19.470010
# Father's qualification                          3000.0    22.408667
# Mother's occupation                             3034.0    11.495715
# Father's occupation                             2952.0    11.597900
# Admission grade                                 2955.0   126.902876
# Displaced                                       2974.0     0.546066
# ...

# %% [markdown]
# Analisis Statistik Deskriptif Dataset Mahasiswa
#
# Age at enrollment (Usia Saat Mendaftar)
#
# Rata-rata usia mahasiswa saat mendaftar adalah sekitar 23 tahun dengan nilai minimum 17 tahun dan maksimum 70 tahun.
#
# Nilai standar deviasi yang cukup tinggi menunjukkan adanya variasi usia yang lebar antar mahasiswa.
#
# Sebagian besar mahasiswa (sekitar 75%) berusia di bawah 25 tahun, menandakan bahwa mayoritas merupakan mahasiswa muda yang baru lulus dari pendidikan sebelumnya.
#
# Admission grade (Nilai Seleksi Masuk)
#
# Nilai rata-rata seleksi masuk sekitar 125, dengan rentang dari 95 hingga 190.
#
# Nilai median 125 menunjukkan bahwa distribusi nilai cukup seimbang.
#
# Nilai maksimum 190 bisa jadi merupakan outlier, menunjukkan mahasiswa dengan performa akademik yang sangat tinggi pada saat seleksi.
#
# Curricular units 1st sem (approved)
#
# Rata-rata mahasiswa menyelesaikan sekitar 4–5 mata kuliah pada semester pertama dengan standar deviasi sekitar 3.0, menandakan adanya variasi performa belajar antar mahasiswa.
#
# Ada mahasiswa yang belum lulus satupun mata kuliah (nilai minimum = 0), sementara ada juga yang lulus hingga 21 mata kuliah, menunjukkan perbedaan kemampuan dan beban studi yang signifikan.
#
# Curricular units 2nd sem (grade)
#
# Nilai rata-rata mahasiswa pada semester kedua adalah sekitar 10.8, dengan nilai maksimum 18.5.
#
# Sebagian besar mahasiswa memiliki nilai sekitar 12–13, menunjukkan performa yang cukup baik dan stabil antar semester.
#
# Unemployment rate dan GDP
#
# Rata-rata tingkat pengangguran pada data ini adalah 11.5%, dengan variasi yang cukup tinggi antar periode.
#
# Nilai GDP rata-rata sekitar 0.028, menunjukkan kondisi ekonomi yang fluktuatif pada masa pengumpulan data.
#
# Adanya hubungan potensial antara faktor ekonomi (GDP dan unemployment rate) dengan performa mahasiswa bisa menjadi bahan analisis lanjutan.
#
# Kesimpulan Umum
#
# Dataset menunjukkan keragaman karakteristik mahasiswa yang cukup besar, baik dari segi usia, prestasi akademik, maupun faktor ekonomi.
#
# Beberapa kolom memiliki outlier atau nilai ekstrim (seperti usia 70 tahun dan nilai 190) yang perlu diperhatikan sebelum melakukan modeling.
#
# Distribusi data secara umum tidak simetris (skewed), sehingga transformasi data atau normalisasi mungkin diperlukan pada tahap pra-pemrosesan.
#
# Secara keseluruhan, data sudah cukup informatif untuk mendukung analisis prediktif terkait performa mahasiswa.

# %% [markdown]
# **5️. Slicing Data**

# %%
df.head(20)
# Out:
#     Unnamed: 0  Student Id Marital status  Application mode  \
# 0            0        6634         single               1.0
# 1            1        6459         single               1.0
# 2            2        2238         single              42.0
# 3            3        2479         single               1.0
# 4            4        4260         single              44.0
# 5            5        3544        married              39.0
# 6            6        4956         single              39.0
# 7            7        6758         single               1.0
# 8            8        2484         single               1.0
# 9            9        9845         single              39.0
# 10          10        3690         single               1.0
# 11          11        2585         single               1.0
# 12          12        5241         single               1.0
# 13          13        2972         single               1.0
# 14          14        2003        married              39.0
# ...

# %%
df.tail(20)
# Out:
#       Unnamed: 0  Student Id Marital status  Application mode  \
# 3076        3076        6757         single              17.0
# 3077        3077        5750         single               1.0
# 3078        3078        2599         single               1.0
# 3079        3079        3249         single              17.0
# 3080        3080        3366       divorced              39.0
# 3081        3081        3462         single              39.0
# 3082        3082        9194         single              17.0
# 3083        3083        5574         single               1.0
# 3084        3084        8311         single               1.0
# 3085        3085        2304         single              17.0
# 3086        3086        6615         single              43.0
# 3087        3087        3759         single               1.0
# 3088        3088        8085         single              51.0
# 3089        3089        1573         single              17.0
# ...

# %%
df.iloc[80:101]
# Out:
#      Unnamed: 0  Student Id Marital status  Application mode  \
# 80           80        1238         single              17.0
# 81           81        4121         single              39.0
# 82           82        2890         single               1.0
# 83           83        4358         single               1.0
# 84           84        4896         single               NaN
# 85           85        4735         single              18.0
# 86           86        1047         single               1.0
# 87           87        7430         single              39.0
# 88           88        8527         single               1.0
# 89           89        5420         single              43.0
# 90           90        5625         single              44.0
# 91           91        8990            NaN               1.0
# 92           92        9143        married              44.0
# 93           93        1944        married               7.0
# ...

# %% [markdown]
# **6️. Tangani nilai yang hilang (NaN) menggunakan salah satu metode berikut:**

# %%
# Mengecek jumlah nilai hilang di setiap kolom
print("=== Jumlah Nilai Hilang per Kolom ===")
print(df.isnull().sum())

# Menghitung total keseluruhan nilai hilang
print("\nTotal nilai hilang di seluruh dataset:", df.isnull().sum().sum())

# Menghapus baris yang seluruh kolomnya kosong (jika ada)
df = df.dropna(how='all')

# Mengisi nilai hilang dengan rata-rata pada kolom numerik
df = df.fillna(df.mean(numeric_only=True))

# Mengecek ulang apakah masih ada nilai hilang
print("\n=== Setelah Penanganan ===")
print(df.isnull().sum())
# Out:
# === Jumlah Nilai Hilang per Kolom ===
# Unnamed: 0                                          0
# Student Id                                          0
# Marital status                                     84
# Application mode                                  172
# Application order                                 108
# Course                                            152
# Daytime/evening attendance\t                       80
# Previous qualification                            123
# Previous qualification (grade)                     85
# Nacionality                                       185
# Mother's qualification                            145
# Father's qualification                             96
# Mother's occupation                                62
# Father's occupation                               144
# Admission grade                                   141
# Displaced                                         122
# Educational special needs                         119
# ...

# %% [markdown]
# **7️. Opsional : Lakukan encoding terhadap kolom bertipe object menjadi numerik menggunakan:**

# %%
# Menampilkan kolom dengan tipe data object (kategori)
print("=== Kolom Kategorikal ===")
kategori_cols = df.select_dtypes(include=['object']).columns
print(kategori_cols)

# Melakukan encoding one-hot untuk kolom kategorikal
df_encoded = pd.get_dummies(df, columns=kategori_cols, drop_first=True)

# Menampilkan hasil encoding
print("\nData setelah encoding:")
display(df_encoded.head())

# Mengecek ukuran data setelah encoding
print("\nUkuran data setelah encoding:", df_encoded.shape)
# Out:
# === Kolom Kategorikal ===
# Index(['Marital status', 'Daytime/evening attendance\t', 'Nacionality',
#        'Target'],
#       dtype='object')
#
# Data setelah encoding:
#    Unnamed: 0  Student Id  Application mode  Application order       Course  \
# 0           0        6634               1.0                3.0  9773.000000
# 1           1        6459               1.0                1.0  8817.929348
# 2           2        2238              42.0                1.0  9500.000000
# 3           3        2479               1.0                1.0  8817.929348
# 4           4        4260              44.0                1.0  8817.929348
#
#    Previous qualification  Previous qualification (grade)  \
# 0                     1.0                      132.647293
# 1                     1.0                      136.000000
# 2                     1.0                      120.000000
# 3                     1.0                      141.000000
# ...

# %% [markdown]
# **8️. Tampilkan kembali dataset yang telah melalui seluruh proses preprocessing (cleaning, imputasi, dan encoding).**

# %%
from sklearn.preprocessing import StandardScaler

# Menyalin dataset hasil encoding agar aman
df_scaled = df_encoded.copy()

# Memilih kolom numerik
num_cols = df_scaled.select_dtypes(include=['int64', 'float64']).columns

# Membuat objek scaler
scaler = StandardScaler()

# Melakukan standarisasi pada kolom numerik
df_scaled[num_cols] = scaler.fit_transform(df_scaled[num_cols])

# Menampilkan hasil normalisasi
print("=== Data Setelah Normalisasi ===")
display(df_scaled.head())

# Mengecek ukuran dataset akhir
print("\nUkuran data setelah normalisasi:", df_scaled.shape)
# Out:
# === Data Setelah Normalisasi ===
#    Unnamed: 0  Student Id  Application mode  Application order    Course  \
# 0   -1.731491    0.450561         -1.044012           0.970177  0.455957
# 1   -1.730373    0.382785         -1.044012          -0.563626  0.000000
# 2   -1.729254   -1.251952          1.362687          -0.563626  0.325625
# 3   -1.728135   -1.158616         -1.044012          -0.563626  0.000000
# 4   -1.727016   -0.468858          1.480087          -0.563626  0.000000
#
#    Previous qualification  Previous qualification (grade)  \
# 0               -0.360317                        0.000000
# 1               -0.360317                        0.255224
# 2               -0.360317                       -0.962773
# 3               -0.360317                        0.635848
# 4                3.354790                       -0.962773
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# ...
