# %% [markdown]
# # Menyiapkan data

# %%
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from IPython.display import display

# atur opsi agar semua kolom terlihat
pd.set_option('display.max_columns', None)

# memuat dataset
df_features = pd.read_csv('features.csv')
df_labels = pd.read_csv('labels.csv')

# %% [markdown]
# # 1️. Tampilkan data yang telah diunduh, kemudian jelaskan semua kolom yang terdapat pada dataset tersebut.

# %%
print("--- 1. Data Awal ---")
print("\nData Features:")
display(df_features.head())

print("\nData Labels:")
display(df_labels.head())
# Out:
# --- 1. Data Awal ---
#
# Data Features:
#    Unnamed: 0  Student Id Marital status  Application mode  Application order  \
# 0           0        6634         single               1.0                3.0
# 1           1        6459         single               1.0                1.0
# 2           2        2238         single              42.0                1.0
# 3           3        2479         single               1.0                1.0
# 4           4        4260         single              44.0                1.0
#
#    Course Daytime/evening attendance\t  Previous qualification  \
# 0  9773.0                          day                     1.0
# 1     NaN                          day                     1.0
# 2  9500.0                          day                     1.0
# 3     NaN                          day                     1.0
# 4     NaN                          day                    39.0
#
#    Previous qualification (grade) Nacionality  Mother's qualification  \
# ...

# %% [markdown]
# # 2️. Lakukan agregasi antara tabel features dengan tabel labels.

# %%
print("--- 2. Agregasi (Penggabungan) Data ---")

# gabungkan kedua tabel dan menghapus kolom yang tidak perlu
df = pd.concat([df_features, df_labels], axis=1)
df = df.drop(columns=['Student Id', 'Unnamed: 0'])

# tampilkan data yang telah digabung
df.head()
# Out:
# --- 2. Agregasi (Penggabungan) Data ---
#   Marital status  Application mode  Application order  Course  \
# 0         single               1.0                3.0  9773.0
# 1         single               1.0                1.0     NaN
# 2         single              42.0                1.0  9500.0
# 3         single               1.0                1.0     NaN
# 4         single              44.0                1.0     NaN
#
#   Daytime/evening attendance\t  Previous qualification  \
# 0                          day                     1.0
# 1                          day                     1.0
# 2                          day                     1.0
# 3                          day                     1.0
# 4                          day                    39.0
#
#    Previous qualification (grade) Nacionality  Mother's qualification  \
# 0                             NaN  Portuguese                     1.0
# 1                           136.0  Portuguese                    19.0
# ...

# %% [markdown]
# # 3️. Tampilkan tipe data dari setiap kolom yang terdapat dalam dataset.

# %%
print(" 3. Tipe Data Setiap Kolom ")

df.info()
# Out:
#  3. Tipe Data Setiap Kolom
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3096 entries, 0 to 3095
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  3012 non-null   object
#  1   Application mode                                2924 non-null   float64
#  2   Application order                               2988 non-null   float64
#  3   Course                                          2944 non-null   float64
#  4   Daytime/evening attendance	                     3016 non-null   object
#  5   Previous qualification                          2973 non-null   float64
#  6   Previous qualification (grade)                  3011 non-null   float64
#  7   Nacionality                                     2911 non-null   object
# ...

# %% [markdown]
# # 4️. Tampilkan statistik deskriptif dari dataset dan berikan analisis singkat mengenai hasilnya.

# %%
print(" 4. Statistik Deskriptif ")

df.describe(include='all')
# Out:
#  4. Statistik Deskriptif
#        Marital status  Application mode  Application order       Course  \
# count            3012       2924.000000        2988.000000  2944.000000
# unique              6               NaN                NaN          NaN
# top            single               NaN                NaN          NaN
# freq             2674               NaN                NaN          NaN
# mean              NaN         18.785568           1.734940  8817.929348
# std               NaN         17.532674           1.327527  2148.407432
# min               NaN          1.000000           1.000000    33.000000
# 25%               NaN          1.000000           1.000000  9085.000000
# 50%               NaN         17.000000           1.000000  9238.000000
# 75%               NaN         39.000000           2.000000  9556.000000
# max               NaN         53.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# ...

# %% [markdown]
# # 5️. Slicing Data
#
#
# * 20 baris awal dari dataset

# %%
print(" 5. Slicing Data (20 Baris Awal) ")
df.head(20)
# Out:
#  5. Slicing Data (20 Baris Awal)
#    Marital status  Application mode  Application order  Course  \
# 0          single               1.0                3.0  9773.0
# 1          single               1.0                1.0     NaN
# 2          single              42.0                1.0  9500.0
# 3          single               1.0                1.0     NaN
# 4          single              44.0                1.0     NaN
# 5         married              39.0                1.0  9853.0
# 6          single              39.0                1.0  9085.0
# 7          single               1.0                4.0  9670.0
# 8          single               1.0                1.0  9773.0
# 9          single              39.0                1.0  9670.0
# 10         single               1.0                1.0  9670.0
# 11         single               1.0                1.0  9070.0
# 12         single               1.0                1.0   171.0
# ...

# %% [markdown]
# * 20 baris terakhir

# %%
print(" 5. Slicing Data (20 Baris Terakhir) ")
df.tail(20)
# Out:
#  5. Slicing Data (20 Baris Terakhir)
#      Marital status  Application mode  Application order  Course  \
# 3076         single              17.0                NaN  9254.0
# 3077         single               1.0                2.0  9500.0
# 3078         single               1.0                1.0  9085.0
# 3079         single              17.0                1.0  9238.0
# 3080       divorced              39.0                1.0  9003.0
# 3081         single              39.0                1.0   171.0
# 3082         single              17.0                5.0  9147.0
# 3083         single               1.0                1.0  9500.0
# 3084         single               1.0                2.0  9773.0
# 3085         single              17.0                1.0  9238.0
# 3086         single              43.0                1.0  9556.0
# 3087         single               1.0                1.0   171.0
# 3088         single              51.0                1.0  9670.0
# ...

# %% [markdown]
# * Baris dari index 80 - 100

# %%
print(" 5. Slicing Data (Baris Index 80-100) ")
df.iloc[80:101]
# Out:
#  5. Slicing Data (Baris Index 80-100)
#     Marital status  Application mode  Application order  Course  \
# 80          single              17.0                1.0  9670.0
# 81          single              39.0                1.0  9003.0
# 82          single               1.0                1.0   171.0
# 83          single               1.0                1.0  9147.0
# 84          single               NaN                1.0  9991.0
# 85          single              18.0                1.0  9500.0
# 86          single               1.0                1.0  9773.0
# 87          single              39.0                2.0  9556.0
# 88          single               1.0                2.0  9500.0
# 89          single              43.0                1.0     NaN
# 90          single              44.0                1.0  9003.0
# 91             NaN               1.0                1.0  9500.0
# 92         married              44.0                1.0  9085.0
# ...

# %% [markdown]
# # 6️. Tangani nilai yang hilang (NaN) menggunakan salah satu metode

# %%
print(" 6. Penanganan Nilai Hilang (Imputasi) ")
print("\nJumlah nilai hilang SEBELUM imputasi:")
print(df.isnull().sum())

# Proses Imputasi
numerical_cols = df.select_dtypes(include=['number']).columns
categorical_cols = df.select_dtypes(include=['object']).columns
df[numerical_cols] = SimpleImputer(strategy='median').fit_transform(df[numerical_cols])
df[categorical_cols] = SimpleImputer(strategy='most_frequent').fit_transform(df[categorical_cols])

print("\nJumlah nilai hilang SETELAH imputasi:")
print(df.isnull().sum())
# Out:
#  6. Penanganan Nilai Hilang (Imputasi)
#
# Jumlah nilai hilang SEBELUM imputasi:
# Marital status                                     84
# Application mode                                  172
# Application order                                 108
# Course                                            152
# Daytime/evening attendance\t                       80
# Previous qualification                            123
# Previous qualification (grade)                     85
# Nacionality                                       185
# Mother's qualification                            145
# Father's qualification                             96
# Mother's occupation                                62
# Father's occupation                               144
# Admission grade                                   141
# Displaced                                         122
# Educational special needs                         119
# Debtor                                            116
# ...

# %% [markdown]
# # 7️. Opsional : Lakukan encoding terhadap kolom bertipe object menjadi numerik menggunakan:
#
#
# *   LabelEncoder, atau
# *   OneHotEncoder

# %%
print(" 7. Encoding Kolom Kategorikal ")

df_encoded = df.copy()
le = LabelEncoder()

for col in categorical_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col])

# Menampilkan hasil setelah encoding
df_encoded.head()
# Out:
#  7. Encoding Kolom Kategorikal
#    Marital status  Application mode  Application order  Course  \
# 0               4               1.0                3.0  9773.0
# 1               4               1.0                1.0  9238.0
# 2               4              42.0                1.0  9500.0
# 3               4               1.0                1.0  9238.0
# 4               4              44.0                1.0  9238.0
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             0                     1.0
# 1                             0                     1.0
# 2                             0                     1.0
# 3                             0                     1.0
# 4                             0                    39.0
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           133.1           13                     1.0
# ...

# %% [markdown]
# # 8️. Tampilkan kembali dataset yang telah melalui seluruh proses preprocessing (cleaning, imputasi, dan encoding).

# %%
print(" 8. Dataset Final Hasil Preprocessing ")

df_final = df_encoded

# Menampilkan hasil akhir
df_final.head()
# Out:
#  8. Dataset Final Hasil Preprocessing
#    Marital status  Application mode  Application order  Course  \
# 0               4               1.0                3.0  9773.0
# 1               4               1.0                1.0  9238.0
# 2               4              42.0                1.0  9500.0
# 3               4               1.0                1.0  9238.0
# 4               4              44.0                1.0  9238.0
#
#    Daytime/evening attendance\t  Previous qualification  \
# 0                             0                     1.0
# 1                             0                     1.0
# 2                             0                     1.0
# 3                             0                     1.0
# 4                             0                    39.0
#
#    Previous qualification (grade)  Nacionality  Mother's qualification  \
# 0                           133.1           13                     1.0
# ...
