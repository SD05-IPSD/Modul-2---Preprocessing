# %%
# Import library utama
import pandas as pd
import numpy as np

# Untuk imputasi dan encoding
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
# Membaca dataset yang telah diunduh dan diupload ke Colab
# Pastikan nama file sesuai yang ada di Drive
features = pd.read_csv('/features.csv')
labels = pd.read_csv('/labels.csv')

# Menampilkan 5 baris pertama dari masing-masing dataset
print("=== Features Dataset ===")
display(features.head())

print("=== Labels Dataset ===")
display(labels.head())
# Out:
# === Features Dataset ===
#    Unnamed: 0  Student Id Marital status  Application mode  Application order  \
# 0           0        6634         single               1.0                3.0
# 1           1        6459         single               1.0                1.0
# 2           2        2238         single              42.0                1.0
# 3           3        2479         single               1.0                1.0
# 4           4        4260         single              44.0                1.0
#
#    Course Daytime/evening attendance\t  Previous qualification  \
# 0  9773.0                          day                     1.0
# 1     NaN                          day                     1.0
# 2  9500.0                          day                     1.0
# 3     NaN                          day                     1.0
# 4     NaN                          day                    39.0
#
#    Previous qualification (grade) Nacionality  ...  \
# ...

# %% [markdown]
#  Penjelasan kolom (contoh, sesuaikan dengan dataset yang sebenarnya)
#
# id: ID unik untuk setiap entri
#
# Age: Usia responden
#
# Gender: Jenis kelamin responden
#
# Income: Pendapatan per bulan
#
# Target: Label hasil klasifikasi

# %%
# Menggabungkan dua tabel berdasarkan kolom 'Student Id'
df = pd.merge(features, labels, left_on='Student Id', right_index=True)

print("=== Dataset Setelah Digabung ===")
display(df.head())
# Out:
# === Dataset Setelah Digabung ===
#     Unnamed: 0  Student Id Marital status  Application mode  \
# 2            2        2238         single              42.0
# 3            3        2479         single               1.0
# 8            8        2484         single               1.0
# 11          11        2585         single               1.0
# 13          13        2972         single               1.0
#
#     Application order  Course Daytime/evening attendance\t  \
# 2                 1.0  9500.0                          day
# 3                 1.0     NaN                          day
# 8                 1.0  9773.0                          day
# 11                1.0  9070.0                          day
# 13                3.0  9500.0                          day
#
#     Previous qualification  Previous qualification (grade) Nacionality  ...  \
# 2                      1.0                           120.0  Portuguese  ...
# ...

# %%
print("=== Tipe Data Tiap Kolom ===")
print(df.dtypes)
# Out:
# === Tipe Data Tiap Kolom ===
# Unnamed: 0                                          int64
# Student Id                                          int64
# Marital status                                     object
# Application mode                                  float64
# Application order                                 float64
# Course                                            float64
# Daytime/evening attendance\t                       object
# Previous qualification                            float64
# Previous qualification (grade)                    float64
# Nacionality                                        object
# Mother's qualification                            float64
# Father's qualification                            float64
# Mother's occupation                               float64
# Father's occupation                               float64
# Admission grade                                   float64
# Displaced                                         float64
# ...

# %%
print("=== Statistik Deskriptif Dataset ===")
display(df.describe(include='all'))

# Analisis singkat
# Mean dan median bisa menggambarkan sebaran data
# Kolom kategorikal (object) nantinya perlu encoding
# Perhatikan nilai min, max, dan std dev untuk melihat sebaran
# Out:
# === Statistik Deskriptif Dataset ===
#          Unnamed: 0   Student Id Marital status  Application mode  \
# count    707.000000   707.000000            685        662.000000
# unique          NaN          NaN              4               NaN
# top             NaN          NaN         single               NaN
# freq            NaN          NaN            607               NaN
# mean    1550.752475  2030.977369            NaN         19.096677
# std      880.976340   609.677577            NaN         17.582217
# min        2.000000  1000.000000            NaN          1.000000
# 25%      780.000000  1509.000000            NaN          1.000000
# 50%     1541.000000  2013.000000            NaN         17.000000
# 75%     2283.000000  2552.500000            NaN         39.000000
# max     3093.000000  3095.000000            NaN         53.000000
#
#         Application order       Course Daytime/evening attendance\t  \
# ...

# %%
# 20 baris pertama
print("=== 20 Baris Pertama ===")
display(df.head(20))

# 20 baris terakhir
print("=== 20 Baris Terakhir ===")
display(df.tail(20))

# Baris dengan index 80 - 100
print("=== Baris Index 80 - 100 ===")
display(df.iloc[80:101])
# Out:
# === 20 Baris Pertama ===
#     Unnamed: 0  Student Id Marital status  Application mode  \
# 2            2        2238         single              42.0
# 3            3        2479         single               1.0
# 8            8        2484         single               1.0
# 11          11        2585         single               1.0
# 13          13        2972         single               1.0
# 14          14        2003        married              39.0
# 15          15        3007         single               7.0
# 31          31        1384         single               1.0
# 34          34        2062         single               1.0
# 38          38        1981         single              44.0
# 49          49        1514         single              18.0
# 54          54        1262         single              44.0
# 55          55        2175         single              39.0
# 58          58        1676         single              39.0
# ...

# %%
# Cek jumlah missing value per kolom
print("=== Jumlah Nilai Hilang Sebelum Imputasi ===")
print(df.isnull().sum())
# Out:
# === Jumlah Nilai Hilang Sebelum Imputasi ===
# Unnamed: 0                                         0
# Student Id                                         0
# Marital status                                    22
# Application mode                                  45
# Application order                                 21
# Course                                            35
# Daytime/evening attendance\t                      14
# Previous qualification                            29
# Previous qualification (grade)                    15
# Nacionality                                       51
# Mother's qualification                            28
# Father's qualification                            20
# Mother's occupation                               14
# Father's occupation                               31
# Admission grade                                   31
# Displaced                                         34
# Educational special needs                         29
# ...

# %%
# Contoh imputasi menggunakan mean untuk kolom numerik
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
imputer_mean = SimpleImputer(strategy='mean')

df[num_cols] = imputer_mean.fit_transform(df[num_cols])

print("=== Jumlah Nilai Hilang Setelah Imputasi ===")
print(df.isnull().sum())
# Out:
# === Jumlah Nilai Hilang Setelah Imputasi ===
# Unnamed: 0                                         0
# Student Id                                         0
# Marital status                                    22
# Application mode                                   0
# Application order                                  0
# Course                                             0
# Daytime/evening attendance\t                      14
# Previous qualification                             0
# Previous qualification (grade)                     0
# Nacionality                                       51
# Mother's qualification                             0
# Father's qualification                             0
# Mother's occupation                                0
# Father's occupation                                0
# Admission grade                                    0
# Displaced                                          0
# Educational special needs                          0
# ...

# %%
# Contoh penggunaan KNNImputer untuk kolom numerik
# Gunakan jika ingin nilai plus
# imputer_knn = KNNImputer(n_neighbors=3)
# df[num_cols] = imputer_knn.fit_transform(df[num_cols])
# print("=== Setelah KNN Imputation ===")
# print(df.isnull().sum())

# %%
# Cek kolom bertipe object
cat_cols = df.select_dtypes(include=['object']).columns
print("Kolom Kategorikal:", cat_cols.tolist())
# Out:
# Kolom Kategorikal: ['Marital status', 'Daytime/evening attendance\t', 'Nacionality', 'Target']

# %%
# Gunakan LabelEncoder untuk kolom kategorikal
le = LabelEncoder()
for col in cat_cols:
    df[col] = le.fit_transform(df[col].astype(str))

print("=== Dataset Setelah Label Encoding ===")
df.head()
# Out:
# === Dataset Setelah Label Encoding ===
#     Unnamed: 0  Student Id  Marital status  Application mode  \
# 2          2.0      2238.0               4              42.0
# 3          3.0      2479.0               4               1.0
# 8          8.0      2484.0               4               1.0
# 11        11.0      2585.0               4               1.0
# 13        13.0      2972.0               4               1.0
#
#     Application order       Course  Daytime/evening attendance\t  \
# 2                 1.0  9500.000000                             0
# 3                 1.0  8740.316964                             0
# 8                 1.0  9773.000000                             0
# 11                1.0  9070.000000                             0
# 13                3.0  9500.000000                             0
#
#     Previous qualification  Previous qualification (grade)  Nacionality  ...  \
# 2                      1.0                           120.0            4  ...
# ...

# %%
print("=== Dataset Final Setelah Preprocessing ===")
display(df.head())
df.info()

# Pastikan tidak ada nilai NaN
print("Jumlah Nilai Hilang:", df.isnull().sum().sum())
# Out:
# === Dataset Final Setelah Preprocessing ===
#     Unnamed: 0  Student Id  Marital status  Application mode  \
# 2          2.0      2238.0               4              42.0
# 3          3.0      2479.0               4               1.0
# 8          8.0      2484.0               4               1.0
# 11        11.0      2585.0               4               1.0
# 13        13.0      2972.0               4               1.0
#
#     Application order       Course  Daytime/evening attendance\t  \
# 2                 1.0  9500.000000                             0
# 3                 1.0  8740.316964                             0
# 8                 1.0  9773.000000                             0
# 11                1.0  9070.000000                             0
# 13                3.0  9500.000000                             0
#
#     Previous qualification  Previous qualification (grade)  Nacionality  ...  \
# 2                      1.0                           120.0            4  ...
# ...

# %%
# Simpan hasil akhir ke file CSV
df.to_csv('/content/NIM_Nama_cleaned.csv', index=False)
print("Dataset final telah disimpan sebagai NIM_Nama_cleaned.csv")
# Out:
# Dataset final telah disimpan sebagai NIM_Nama_cleaned.csv
