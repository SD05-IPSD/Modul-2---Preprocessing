# %% [markdown]
# **Nama: Anindya Sukma Dwiyanda**
#
#
# **NIM: 103132400006**
#
# **Kelas: S1SD-04-01**

# %% [markdown]
# **Import Library**

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# **Load Dataset**

# %%
features = pd.read_csv("features.csv")
labels = pd.read_csv("labels.csv")

# %% [markdown]
# **1. Tampilkan data yang tehlah diunduh dan penjelasan kolom pada dataset**

# %%
# Menampilkan data dari features
features.head().T
# Out:
#                                                          0           1  \
# Unnamed: 0                                               0           1
# Student Id                                            6634        6459
# Marital status                                      single      single
# Application mode                                       1.0         1.0
# Application order                                      3.0         1.0
# Course                                              9773.0         NaN
# Daytime/evening attendance\t                           day         day
# Previous qualification                                 1.0         1.0
# Previous qualification (grade)                         NaN       136.0
# Nacionality                                     Portuguese  Portuguese
# Mother's qualification                                 1.0        19.0
# Father's qualification                                 1.0        19.0
# ...

# %%
# Menampilkan data dari labels
labels
# Out:
#         Target
# 0     Graduate
# 1     Graduate
# 2     Graduate
# 3     Graduate
# 4      Dropout
# ...        ...
# 3091  Graduate
# 3092  Graduate
# 3093  Graduate
# 3094   Dropout
# 3095  Graduate
#
# [3096 rows x 1 columns]

# %% [markdown]
# Penjelasan dari tabel:
#
#
# 1. Unnamed: 0 & Student ID: Nomor identififkasi untuk setiap mahasiswa
# 2. Marital Status: Status pernikahan mahasiswa saat mendaftar
# 3. Application mode: Kode atau cara mahasiswa mendaftar ke institusi
# 4. Application order: Urutan pilihan program studi/aplikasi yang diajukan
# 5. Daytime/evening attendance\t: Indikator apakah mahasiwa mengikuti kelas siang atau malam
# 6. Previous qualification: Kualifikasi pendidikan terakhir sebelum mendaftar
# 7. Previous qualification (grade): Nilai rata-rata atau IPK dari kualifikasi pendidikan sebelumnya
# 8. Nacionality: Kebangsaan atau asal negaara mahasiswa
# 9. Mother's qualification: Kualifikasi pendidikan terakhir ibu
# 10. Father's qualification: Kualifikasi pendidikan terakhir ayah
# 11. Mother's occupation: Pekerjaan utama ibu mahaasiswa
# 12. Father's occupation: Pekerjaan utama ayah mahasiswa
# 13. Admission grade: Nilai yang digunakan sebagai dasar penerimaan mahasiswa
# 14. Displaced: Indikator apakah mahasiswa harus pindah tempat tinggal
# 15. Educational special needs: Indikator apakah mahasiswa memiliki kebutuhan pendidikan khusus
# 16. Debtor: Indikator apakah mahasiswa memiliki tunggakan/utang biaya kuliah
# 17. Tuition fees up to date: Indikator apakah biaya kuliah mahasiswa sudah lunas atau diperbarui tepat waktu
# 18. Gender: Jenis kelamin mahasiswa
# 19. Scholarship holder: Indikator apakah mahasiswa menerima beasiswa
# 20. Age at enrollment: Usia mahasiswa saat pertama kali mendaftar/masuk
# 21. International: Indikator apakah mahasiswa tersebut adalah mahasiswa internasional
# 22. Curricular units 1st sem (credited):  Jumlah matkul sem 1 yang diakui
# 23. Curricular units 1st sem (enrolled): Jumlah SKS/matkul yang diambil/didaftarkan pada semester 1
# 24. Curricular units 1st sem (evaluations): Jumlah evaluasi/ujian yang diikuti pada sem 1
# 25. Curricular units 1st sem (approved): Jumlah SKS/matkul yang berhasil lulus pada sem 1
# 26. Curricular units 1st sem (grade): Rata-rata nilai yang diperoleh mahasiswa pada semester 1
# 27. Curricular units 1st sem (without evaluations): Matkul sem 1 yang tidak diikuti ujian
# 28. Curricular units 2nd sem (credited): Jumlah matkul sem 2 yang diakui
# 29. Curricular units 2nd sem (enrolled): Jumlah SKS/matkul yang diambil/didaftarkan pada semester 2
# 30. Curricular units 2nd sem (evaluations): Jumlah evaluasi/ujian yang diikuti pada sem 2
# 31. Curricular units 2nd sem (approved): Jumlah SKS/matkul yang berhasil lulus pada sem 2
# 32. Curricular units 2nd sem (grade): Rata-rata nilai yang diperoleh mahasiswa pada semester 2
# 33. Curricular units 2nd sem (without evaluations): Jumlah evaluasi/ujian yang diikuti pada sem 2
# 34. Unemployment rate: Tingkat pengangguran pada periode pendaftaran
# 35. Inflation rate: Tingkat inflasi pada periode pendaftaran
# 36. GDP: Produk domestik pada periode pendaftaran

# %% [markdown]
# **2. Melakukan agregasi antara tabel features dengan tabel labels.**

# %%
df = pd.concat([features, labels], axis=1)
df.head()
# Out:
#    Unnamed: 0  Student Id Marital status  Application mode  Application order  \
# 0           0        6634         single               1.0                3.0
# 1           1        6459         single               1.0                1.0
# 2           2        2238         single              42.0                1.0
# 3           3        2479         single               1.0                1.0
# 4           4        4260         single              44.0                1.0
#
#    Course Daytime/evening attendance\t  Previous qualification  \
# 0  9773.0                          day                     1.0
# 1     NaN                          day                     1.0
# 2  9500.0                          day                     1.0
# 3     NaN                          day                     1.0
# 4     NaN                          day                    39.0
#
#    Previous qualification (grade) Nacionality  ...  \
# 0                             NaN  Portuguese  ...
# ...

# %% [markdown]
# **3. Menampilkan tipe data dari setiap kolom yang terdapat dalam dataset.**

# %%
# Menampilkan tipe data setiap kolom
df.dtypes
# Out:
# Unnamed: 0                                          int64
# Student Id                                          int64
# Marital status                                     object
# Application mode                                  float64
# Application order                                 float64
# Course                                            float64
# Daytime/evening attendance\t                       object
# Previous qualification                            float64
# Previous qualification (grade)                    float64
# Nacionality                                        object
# Mother's qualification                            float64
# Father's qualification                            float64
# Mother's occupation                               float64
# Father's occupation                               float64
# Admission grade                                   float64
# Displaced                                         float64
# ...

# %%
# Menampilkan informasi data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3096 entries, 0 to 3095
# Data columns (total 39 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Unnamed: 0                                      3096 non-null   int64
#  1   Student Id                                      3096 non-null   int64
#  2   Marital status                                  3012 non-null   object
#  3   Application mode                                2924 non-null   float64
#  4   Application order                               2988 non-null   float64
#  5   Course                                          2944 non-null   float64
#  6   Daytime/evening attendance	                     3016 non-null   object
#  7   Previous qualification                          2973 non-null   float64
#  8   Previous qualification (grade)                  3011 non-null   float64
# ...

# %% [markdown]
# **4. Statistik Deskriptif dan Analisis Singkat**

# %%
# Menampilkan statistik deskriptif
df.describe().T
# Out:
#                                                  count         mean  \
# Unnamed: 0                                      3096.0  1547.500000
# Student Id                                      3096.0  5470.623062
# Application mode                                2924.0    18.785568
# Application order                               2988.0     1.734940
# Course                                          2944.0  8817.929348
# Previous qualification                          2973.0     4.685503
# Previous qualification (grade)                  3011.0   132.647293
# Mother's qualification                          2951.0    19.470010
# Father's qualification                          3000.0    22.408667
# Mother's occupation                             3034.0    11.495715
# Father's occupation                             2952.0    11.597900
# Admission grade                                 2955.0   126.902876
# Displaced                                       2974.0     0.546066
# ...

# %% [markdown]
# Analisis singkat
#
# 1. Profil mahasiswa
#
#
# *   Tujuan akademik: status akhir mahasiswa dominan "Graduate", yang merupakan kategori top dengan frekuensi tertinggi (2.209 entri). ini menunjukkan mayoritas mahasiswa berhasil lulus, tetapi perlu diperhatikan bahwa 'Dropout' juga memiliki frekuensi yang signifikan
# *   Usia: rata-rata usia mahsiswa saat mendaftar adalah 23.36 tahun, dengan usia termuda 17 tahun dan tertua 70 tahun. standar deviasi yang cukup besar (std = 8.04) menunjukkan variasi usia yang luas, tidak hanya diisi lulusan sma.
# *   Nilai masuk: rata-rata nilai penerimaan adalah 126.98 dengan variasi yang tidak terlalu ekstrem (std = 14.48)
#
# 2. Kualitas Data
# *   Terdapat beberapa kolom dengan nilai hilang yang signifikan, terlihat dari count yang kurang dari 4424. hal ini menggarisbawahi pentingnya langkah  (imputasi) dalam tugas preprocessing untuk menangani data yang hilang
#
# 3. Kinerja Akademik
# *   Rata-rata nilai: rata0rata nilai yang  diperoleh mhasiswa di semester 1 dan  di semester 2 sedikit lebih tinggi yaitu 13.43
# *   Beban studi: mahasiswa rata-rata mengambil 6 matakuliah dan meluluskan sekitar 4 matakuliah per semester, menunjukkan adanya tantangan dalam menyelesaikan semua mata kuliah.

# %% [markdown]
# **5. SLICING**

# %%
# Contoh Slicing menggunakan iloc: Mengambil 5 baris pertama dan 5 kolom pertama
df.iloc[:5, :5]
# Out:
#    Unnamed: 0  Student Id Marital status  Application mode  Application order
# 0           0        6634         single               1.0                3.0
# 1           1        6459         single               1.0                1.0
# 2           2        2238         single              42.0                1.0
# 3           3        2479         single               1.0                1.0
# 4           4        4260         single              44.0                1.0

# %% [markdown]
# **6. Encoding**

# %%
encoder = LabelEncoder()

# Encoding semua kolom bertipe object
for col in df_imputed.select_dtypes(include=['object']).columns:
    df_imputed[col] = encoder.fit_transform(df_imputed[col])

df_imputed.head()
# Out:
#    Unnamed: 0  Student Id  Application mode  Application order  Course  \
# 0         0.0      6634.0               1.0                3.0  9773.0
# 1         1.0      6459.0               1.0                1.0  9130.2
# 2         2.0      2238.0              42.0                1.0  9500.0
# 3         3.0      2479.0               1.0                1.0  5687.8
# 4         4.0      4260.0              44.0                1.0  9388.2
#
#    Previous qualification  Previous qualification (grade)  \
# 0                     1.0                           141.0
# 1                     1.0                           136.0
# 2                     1.0                           120.0
# 3                     1.0                           141.0
# 4                    39.0                           120.0
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                     1.0                     1.0                  4.0  ...
# ...

# %%
# Menampilkan missing value setelah pre processing
df_imputed.isnull().sum()
# Out:
# Unnamed: 0                                        0
# Student Id                                        0
# Application mode                                  0
# Application order                                 0
# Course                                            0
# Previous qualification                            0
# Previous qualification (grade)                    0
# Mother's qualification                            0
# Father's qualification                            0
# Mother's occupation                               0
# Father's occupation                               0
# Admission grade                                   0
# Displaced                                         0
# Educational special needs                         0
# Debtor                                            0
# Tuition fees up to date                           0
# Gender                                            0
# Scholarship holder                                0
# ...

# %%
imputer = KNNImputer(n_neighbors=5)
df_imputed = pd.DataFrame(imputer.fit_transform(df.select_dtypes(include=np.number)), columns=df.select_dtypes(include=np.number).columns)

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df_imputed[col] = encoder.fit_transform(df[col])

df_imputed.head()
# Out:
#    Unnamed: 0  Student Id  Application mode  Application order  Course  \
# 0         0.0      6634.0               1.0                3.0  9773.0
# 1         1.0      6459.0               1.0                1.0  9130.2
# 2         2.0      2238.0              42.0                1.0  9500.0
# 3         3.0      2479.0               1.0                1.0  5687.8
# 4         4.0      4260.0              44.0                1.0  9388.2
#
#    Previous qualification  Previous qualification (grade)  \
# 0                     1.0                           141.0
# 1                     1.0                           136.0
# 2                     1.0                           120.0
# 3                     1.0                           141.0
# 4                    39.0                           120.0
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                     1.0                     1.0                  4.0  ...
# ...

# %% [markdown]
# **7. Menampilkan dataset**

# %%
print("Shape dataset akhir:", df_imputed.shape)
df_imputed.head()
# Out:
# Shape dataset akhir: (3096, 35)
#    Unnamed: 0  Student Id  Application mode  Application order  Course  \
# 0         0.0      6634.0               1.0                3.0  9773.0
# 1         1.0      6459.0               1.0                1.0  9130.2
# 2         2.0      2238.0              42.0                1.0  9500.0
# 3         3.0      2479.0               1.0                1.0  5687.8
# 4         4.0      4260.0              44.0                1.0  9388.2
#
#    Previous qualification  Previous qualification (grade)  \
# 0                     1.0                           141.0
# 1                     1.0                           136.0
# 2                     1.0                           120.0
# 3                     1.0                           141.0
# 4                    39.0                           120.0
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# ...
